# %%
import fastf1 as ff1
from fastf1 import plotting
import pandas as pd

ff1.Cache.enable_cache("cache")
plotting.setup_mpl()

# %%
qa = ff1.get_session(2022, "Bahrain", "R")
qa.load(telemetry=True)
# Out:
# core           INFO 	Loading data for Bahrain Grand Prix - Race [v2.2.1]
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# core           INFO 	Finished loading data for 20 drivers: ['16', '55', '44', '63', '20', '77', '31', '22', '14', '24', '47', '18', '23', '3', '4', '6', '27', '11', '1', '10']

# %%
qp = ff1.get_session(2021, "Bahrain", "R")
qp.load(telemetry=True)
# Out:
# core           INFO 	Loading data for Bahrain Grand Prix - Race [v2.2.1]
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# core           INFO 	Finished loading data for 20 drivers: ['44', '33', '77', '4', '11', '16', '3', '55', '22', '18', '7', '99', '31', '63', '5', '47', '10', '6', '14', '9']

# %%
actual_perez = qa.laps.pick_driver("PER").pick_fastest().get_car_data().add_distance()
past_perez = qp.laps.pick_driver("PER").pick_fastest().get_car_data().add_distance()

# %%
actual_perez
# Out:
#                        Date    RPM  Speed  nGear  Throttle  Brake  DRS Source  \
# 0   2022-03-20 16:31:39.282  11373    287      7       100  False    1    car
# 1   2022-03-20 16:31:39.522  11443    288      7       100  False    1    car
# 2   2022-03-20 16:31:39.962  10436    291      7       100  False    1    car
# 3   2022-03-20 16:31:40.282  10430    292      8       100  False    1    car
# 4   2022-03-20 16:31:40.442  10517    292      8       100  False    1    car
# ..                      ...    ...    ...    ...       ...    ...  ...    ...
# 351 2022-03-20 16:33:13.923  10892    273      7       100  False    1    car
# 352 2022-03-20 16:33:14.203  11080    277      7       100  False    1    car
# 353 2022-03-20 16:33:14.403  11128    280      7       100  False    1    car
# 354 2022-03-20 16:33:14.643  11145    281      7       100  False    1    car
# 355 2022-03-20 16:33:14.883  11287    284      7       100  False    1    car
#
# ...

# %%
actual_perez["Session"] = "2022"
past_perez["Session"] = "2021"

perez = pd.concat([actual_perez, past_perez], axis=0)

# %%
import plotly.express as px

fig = px.line(perez, "Distance", "Speed", color="Session")
fig.show()

# %%
fig = px.line(perez, "Distance", "Throttle", color="Session")
fig.show()

# %%
fig = px.line(perez, "Distance", "nGear", color="Session")
fig.show()
